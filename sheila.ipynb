# %% [markdown]
# <a href="https://colab.research.google.com/github/igorchl/TRAB/blob/main/sheila.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x = np.array([i for i in range(5)])
y = np.array([i for i in range(5)])

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y)

# %%
from random import uniform

ws = np.array([round(uniform(-1, 1),3) for i in range(2)])
ws
# Out:
# array([-0.17 ,  0.874])

# %%
def hipotese(w0, w1, x):
  return w0 + w1*x

# %%
hipotese(ws[0], ws[1], x)
# Out:
# array([-0.17 ,  0.704,  1.578,  2.452,  3.326])

# %%
plt.scatter(x, y)
plt.plot(x, hipotese(ws[0], ws[1], x))

# %%
def MSE(w0, w1, x, y):
  return np.sum((hipotese(w0,w1,x) - y)**2)/len(x)

# %%
MSE(ws[0], ws[1], x, y)
# Out:
# 0.209836
